# %%
print("Rohan")
# Out:
# Rohan

# %%
#types
#type 1:using parenthesis
nums=(1,2,3,4,5)
colors=("re","blue","green")
mixed=("Raj",23,54.8,True)
nested=(23,(2,4),[2,5,6])
#type2: without parenthesis
fruits="apple","banana","mango"
#type3: using tuple constructor
values=tuple((1,2,3,4,5,6))
print(values,type(values))
list_item=[10,20,30,40,]
list_tup=tuple(list_item)
#type4:single value
num=(10,)
print(num,type(num))
# Out:
# (1, 2, 3, 4, 5, 6) <class 'tuple'>
# (10,) <class 'tuple'>

# %%
colors=("red","blue","green")
#         0      1      2
#colors[1]="pink"#does not support item assignment
#print(colors)
#if you want to change
#1. conver to list
list_colors=list(colors)
list_colors[1]="pink"
colors=tuple(list_colors)
print(colors,type(colors))
# Out:
# ('red', 'pink', 'green') <class 'tuple'>

# %% [markdown]
# tuple methods and function

# %%
nums=(10,30,50,20,40,15,5)
print(max(nums))#max
print(min(nums))#min
sort_nums=sorted(nums)#sorting
print("count",nums.count(50))#count
print("index",nums.index(30))#index
# Out:
# 50
# 5
# count 1
# index 1
